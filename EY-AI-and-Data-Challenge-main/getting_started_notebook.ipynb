# %% [markdown]
# # Getting Started with Snowflake Notebooks
#
# Welcome to the 2026 EY Data & AI Challenge!
#
# This notebook will get you up and running with Snowflake Notebooks. By the end, you'll see how Snowflake can help you leverage a powerful cloud-computing environment to gather satellite imagery data from an external source and conduct geospatial analyses using that data. Once you successfully run this notebook, you will understand the steps required to use Python notebooks for the data challenge. Dive in and have fun !!!

# %% [markdown]
# ## Confirm setup of External Access Integration (EAI)
#
# Before running this notebook, you will need to run a SQL script to create an [External Access Integration](https://docs.snowflake.com/en/developer-guide/external-network-access/external-network-access-overview).
#
# This script creates external network access to install PyPI packages and access Planetary Computer API endpoints.
#
# The setup script can be accessed directly within Snowflake using this [deeplink](https://app.snowflake.com/templates?template=setup_account_data_challenge_template).
#
# The SQL script is also located in the Snowflake-Labs repo on [Github](https://github.com/Snowflake-Labs/sfquickstarts/tree/master/site/sfguides/src/ey-ai-and-data-challenge).
#
# An EAI relies upon network rules that are stored in a database. You can attach many rules to the same policy. This same process can be used to setup other access points for external datasets from Google or Amazon.
#
# Snowflake notebooks can run SQL and Python cells. When you run the next cell, you should see a dialog box where you can choose which External Access Integration you wish to use. Select "DATA_CHALLENGE_EXTERNAL_ACCESS". Click "Create and Connect." It will take 2-3 minutes for the kernel to connect to the container service.
#
# When you see that the kernel status is "Connected", then the SQL cell will run, and "DATA_CHALLENGE_EXTERNAL_ACCESS" will be listed in the output.

# %%
show integrations;
# Out:
#   Cell In[2], line 1
#     show integrations;
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Import Python packages
# Snowflake Notebooks have 2 runtime options: On Warehouse or On Container.
# When you run Snowflake Notebooks inside Snowflake Workspaces, notebooks run on Container, so you can easily use "pip install" to load python libraries.
#
# The Container runtime contains Streamlit and many other third-party packages (by default)[https://docs.snowflake.com/en/developer-guide/snowflake-ml/container-runtime-ml#snowflake-runtime-packages].
#
# You can add any additional packages from [PyPI- Python Package Index](www.pypi.org) by loading all dependencies in a **requirements.txt** file. You can create the file by running the Python cell below, or manually upload your **requirements.txt** file into the same folder as this notebook using the plus button in the left sidebar.

# %%
# Step 1: Create the requirements.txt file locally
requirements = """
rioxarray==0.17.0
pystac==1.11.0
pystac_client==0.9.0
planetary_computer==1.0.0
odc-stac==0.3.10
shapely==2.1.1
rasterio==1.4.3
tqdm==4.66.5
pandas==2.3.0
xarray==2025.3.1
matplotlib==3.10.3
geopandas==1.1.1
seaborn==0.13.2
scikit-learn==1.5.2
netCDF4==1.7.2
adlfs==2025.8.0
zarr==2.17.2
dask==2024.10.0
xarray[complete]
numcodecs==0.12.1
"""

with open('requirements.txt', 'w') as f:
    f.write(requirements)

print("File created locally")
# Out:
# File created locally

# %% [markdown]
# **Note:** Please use one of the below mentioned steps to save requirements.txt file as per your workspace configuration.

# %% [markdown]
# **Save requirements.txt file in the default workspace named 'My Workspace'**

# %% [markdown]
# **Save requirements.txt file in the workspace named 'EY-AI-and-Data-Challenge'**

# %% [markdown]
# **Note:** If you're using the workspace with some other name, then please remember to replace "EY-AI-and-Data-Challenge" with your workspace name in the file path.

# %% [markdown]
# ## Python Package Management
#
# Snowflake Notebooks operate similar to Jupyter notebooks that run in your local environment, with one significant difference in the way storage is handled.
#
# When you run "pip install" in your local environment, there is a physical folder structure where the packages are stored. In Snowflake, there are 2 storage layers: the persistent storage layer (that you can see in the sidebar to the left) and the container storage layer that resets each time your Notebook Container Service restarts.
#
# By default, the Notebook Service has an idle timeout of 24 hours, but the Compute Pool (which uses Snowflake Credits) has an idle timeout of 5 minutes. This means that after 5 minutes, you stop using up your Snowflake Credits, but the variables and packages in the kernel will remain active for 24 hours. For more information, read the [Snowflake Docs](https://docs.snowflake.com/en/user-guide/ui-snowsight/notebooks-in-workspaces/notebooks-in-workspaces-compute-setup).

# %%
import time

start_time = time.time()
print("Installing packages to shared directory...")
print("This may take a few minutes...\n")

# Install all packages from requirements.txt to the shared directory
# !pip install -r requirements.txt 

elapsed_time = time.time() - start_time
print(f"\n✓ Package installation complete!")
print(f"  Time elapsed: {elapsed_time:.1f} seconds ({elapsed_time/60:.1f} minutes)")
# Out:
# Installing packages to shared directory...
# This may take a few minutes...
#
# Requirement already satisfied: rioxarray==0.17.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 2)) (0.17.0)
# Requirement already satisfied: pystac==1.11.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: pystac_client==0.9.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: planetary_computer==1.0.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: odc-stac==0.3.10 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 6)) (0.3.10)
# Requirement already satisfied: shapely==2.1.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 7)) (2.1.1)
# Requirement already satisfied: rasterio==1.4.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: tqdm==4.66.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 9)) (4.66.5)
# Requirement already satisfied: pandas==2.3.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: xarray==2025.3.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 11)) (2025.3.1)
# Requirement already satisfied: matplotlib==3.10.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 12)) (3.10.3)
# Requirement already satisfied: geopandas==1.1.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 13)) (1.1.1)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 14)) (0.13.2)
# Requirement already satisfied: scikit-learn==1.5.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 15)) (1.5.2)
# Requirement already satisfied: netCDF4==1.7.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 16)) (1.7.2)
# Requirement already satisfied: adlfs==2025.8.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 17)) (2025.8.0)
# Requirement already satisfied: zarr==2.17.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 18)) (2.17.2)
# Requirement already satisfied: dask==2024.10.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 19)) (2024.10.0)
# Requirement already satisfied: numcodecs==0.12.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from -r requirements.txt (line 21)) (0.12.1)
# Requirement already satisfied: packaging in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rioxarray==0.17.0->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyproj>=3.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rioxarray==0.17.0->-r requirements.txt (line 2)) (3.7.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rioxarray==0.17.0->-r requirements.txt (line 2)) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pystac==1.11.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: requests>=2.28.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pystac_client==0.9.0->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: click>=7.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: pydantic>=1.7.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 5)) (2.12.5)
# Requirement already satisfied: pytz>=2020.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: python-dotenv in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: affine in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from odc-stac==0.3.10->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: odc-geo>=0.4.7 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from odc-stac==0.3.10->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: toolz in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from odc-stac==0.3.10->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: attrs in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rasterio==1.4.3->-r requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: certifi in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rasterio==1.4.3->-r requirements.txt (line 8)) (2026.1.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rasterio==1.4.3->-r requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rasterio==1.4.3->-r requirements.txt (line 8)) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from rasterio==1.4.3->-r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: colorama in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from tqdm==4.66.5->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pandas==2.3.0->-r requirements.txt (line 10)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from matplotlib==3.10.3->-r requirements.txt (line 12)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from matplotlib==3.10.3->-r requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from matplotlib==3.10.3->-r requirements.txt (line 12)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from matplotlib==3.10.3->-r requirements.txt (line 12)) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from matplotlib==3.10.3->-r requirements.txt (line 12)) (12.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from geopandas==1.1.1->-r requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 15)) (1.17.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: cftime in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from netCDF4==1.7.2->-r requirements.txt (line 16)) (1.6.5)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (1.38.2)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (0.0.53)
# Requirement already satisfied: azure-identity in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (1.25.2)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (12.28.0)
# Requirement already satisfied: fsspec>=2023.12.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (2026.2.0)
# Requirement already satisfied: aiohttp>=3.7.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from adlfs==2025.8.0->-r requirements.txt (line 17)) (3.13.3)
# Requirement already satisfied: asciitree in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from zarr==2.17.2->-r requirements.txt (line 18)) (0.3.3)
# Requirement already satisfied: fasteners in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from zarr==2.17.2->-r requirements.txt (line 18)) (0.20)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (3.1.2)
# Requirement already satisfied: partd>=1.4.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (6.0.3)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (8.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-core<2.0.0,>=1.28.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (4.15.0)
# Requirement already satisfied: cffi in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: msal<2,>=1.16.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 17)) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-storage-blob>=12.17.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (46.0.5)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-storage-blob>=12.17.0->adlfs==2025.8.0->-r requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from importlib-metadata>=4.13.0->dask==2024.10.0->-r requirements.txt (line 19)) (3.23.0)
# Requirement already satisfied: cachetools in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from odc-geo>=0.4.7->odc-stac==0.3.10->-r requirements.txt (line 6)) (7.0.1)
# Requirement already satisfied: locket in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from partd>=1.4.0->dask==2024.10.0->-r requirements.txt (line 19)) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 5)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pystac==1.11.0->-r requirements.txt (line 3)) (4.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from python-dateutil>=2.7.0->pystac==1.11.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from requests>=2.28.2->pystac_client==0.9.0->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from requests>=2.28.2->pystac_client==0.9.0->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from requests>=2.28.2->pystac_client==0.9.0->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from azure-identity->adlfs==2025.8.0->-r requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: bottleneck in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: numbagg in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (0.9.4)
# Requirement already satisfied: numba>=0.54 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (0.64.0)
# Requirement already satisfied: flox in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (0.11.1)
# Requirement already satisfied: opt_einsum in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: h5netcdf in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (1.8.1)
# Requirement already satisfied: pooch in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: sparse in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (0.18.0)
# Requirement already satisfied: cartopy in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (0.25.0)
# Requirement already satisfied: nc-time-axis in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from xarray==2025.3.1->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: pycparser in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 17)) (3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from jsonschema~=4.18->pystac==1.11.0->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from jsonschema~=4.18->pystac==1.11.0->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from jsonschema~=4.18->pystac==1.11.0->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 17)) (2.11.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from numba>=0.54->xarray==2025.3.1->-r requirements.txt (line 11)) (0.46.0)
# Requirement already satisfied: pyshp>=2.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from cartopy->xarray==2025.3.1->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: pyarrow>=14.0.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (23.0.1)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (4.4.5)
# Requirement already satisfied: numpy_groupies>=0.9.19 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from flox->xarray==2025.3.1->-r requirements.txt (line 11)) (0.11.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from pooch->xarray==2025.3.1->-r requirements.txt (line 11)) (4.9.2)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (1.1.16)
# Requirement already satisfied: bokeh>=3.1.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (3.8.2)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: distributed==2024.10.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from dask==2024.10.0->-r requirements.txt (line 19)) (2024.10.0)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (7.2.2)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (6.5.4)
# Requirement already satisfied: zict>=3.0.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 19)) (3.0.0)
# Requirement already satisfied: narwhals>=1.13 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from bokeh>=3.1.0->dask==2024.10.0->-r requirements.txt (line 19)) (2.17.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from bokeh>=3.1.0->dask==2024.10.0->-r requirements.txt (line 19)) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\celso\onedrive\área de trabalho\work in progress\ey-ai-and-data-challenge-main\ey-ai-and-data-challenge-main\.venv\lib\site-packages (from jinja2>=2.10.3->dask==2024.10.0->-r requirements.txt (line 19)) (3.0.3)
#
# ✓ Package installation complete!
#   Time elapsed: 10.0 seconds (0.2 minutes)
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Restart Kernel
#
# After installing packages, it is necessary to restart the kernel, to access the new python packages.
# Click the "⌄" symbol next to the  "Connect/Connected" button at the top of the editing pane in [Snowflake Workspaces](https://docs.snowflake.com/en/user-guide/ui-snowsight/notebooks-in-workspaces/notebooks-in-workspaces-overview).

# %% [markdown]
# ## Load Python Dependencies

# %%
# Import common GIS tools
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# Import Planetary Computer tools
import pystac_client
import planetary_computer as pc
from odc.stac import stac_load

import dask
import dask.array as da

# %% [markdown]
# # Load the satellite data
# First, we define our area of interest using latitude and longitude coordinates of the centroid. Then we define the size of the surrounding bounding box (in degrees). Finally, we define the time window.

# %%
# Sample region in South Africa
# Contains Water Quality Sample Site #184 and #186 on the Wilge River
lat_long = (-27.2923, 28.5365) # Lat-Lon centroid location
box_size_deg = 0.15 # Surrounding box in degrees

# %%
# Calculate the Lat-Lon bounding box region
min_lon = lat_long[1]-box_size_deg/2
min_lat = lat_long[0]-box_size_deg/2
max_lon = lat_long[1]+box_size_deg/2
max_lat = lat_long[0]+box_size_deg/2
bounds = (min_lon, min_lat, max_lon, max_lat)

# %%
# Define the time window
time_window="2015-01-01/2015-05-01"

# %% [markdown]
# Using the `pystac_client` we can search the Microsoft Planetary Computer's STAC catalog for items matching our query parameters. The result is the number of scenes matching our search criteria that touch our area of interest. Some of these may be partial scenes and may contain clouds. We have included both Landsat-7 and Landsat-8 data and filtered for low-cloud (<10%) scenes.

# %%
stac = pystac_client.Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")
search = stac.search(
    collections=["landsat-c2-l2"], 
    bbox=bounds, 
    datetime=time_window,
    query={"platform": {"in": ["landsat-7", "landsat-8"]}, "eo:cloud_cover": {"lt": 10}},
)
items = list(search.get_all_items())
print('This is the number of scenes that touch our region:',len(items))
# Out:
# This is the number of scenes that touch our region: 6
# c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\pystac_client\item_search.py:940: FutureWarning: get_all_items() is deprecated, use item_collection() instead.
#   warnings.warn(

# %% [markdown]
# Next, we'll load the data into an [xarray](https://xarray.pydata.org/en/stable/) DataArray using the Open Data Cube (ODC) STAC [odc-stac](https://odc-stac.readthedocs.io/en/latest/index.html) library. The ODC [odc](https://www.opendatacube.org) is an open source geospatial data management and analysis software project that is used globally for many projects (e.g., Digital Earth Africa). The ODC-STAC code will load the selected items from the catalog search, select the desired spectral bands, including the "qa_pixel" cloud filtering band, reproject into Lat-Lon coordinates (EPSG:4326) at 30-meters resolution (typical of Landsat pixel resolution), and clip the region to the spatial bounding box.

# %%
# Define the pixel resolution for the final product
# Define the scale according to our selected crs, so we will use degrees
resolution = 30  # meters per pixel 
scale = resolution / 111320.0 # degrees per pixel for CRS:4326

# %%
xx = stac_load(
    items,
    bands=["red", "green", "blue", "nir08", "swir16", "swir22", "qa_pixel"],
    crs="EPSG:4326", # Latitude-Longitude
    resolution=scale, # Degrees
    chunks={"x": 2048, "y": 2048},
    patch_url=pc.sign,
    bbox=bounds
)

# %%
# Apply scaling and offsets for Landsat Collection-2 (reference below) to the spectral bands ONLY
# https://planetarycomputer.microsoft.com/dataset/landsat-c2-l2
xx['red'] = (xx['red']*0.0000275)-0.2
xx['green'] = (xx['green']*0.0000275)-0.2
xx['blue'] = (xx['blue']*0.0000275)-0.2
xx['nir08'] = (xx['nir08']*0.0000275)-0.2
xx['swir16'] = (xx['swir16']*0.0000275)-0.2
xx['swir22'] = (xx['swir22']*0.0000275)-0.2

# %%
# View the dimensions of our XARRAY and the variables
display(xx)
# Out:
# <xarray.Dataset> Size: 93MB
# Dimensions:      (latitude: 557, longitude: 557, time: 6)
# Coordinates:
#   * latitude     (latitude) float64 4kB -27.22 -27.22 -27.22 ... -27.37 -27.37
#   * longitude    (longitude) float64 4kB 28.46 28.46 28.46 ... 28.61 28.61 28.61
#     spatial_ref  int32 4B 4326
#   * time         (time) datetime64[ns] 48B 2015-01-03T08:02:45.736685 ... 201...
# Data variables:
#     red          (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     green        (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     blue         (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     nir08        (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     swir16       (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     swir22       (time, latitude, longitude) float64 15MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>
#     qa_pixel     (time, latitude, longitude) uint16 4MB dask.array<chunksize=(1, 557, 557), meta=np.ndarray>

# %% [markdown]
# ## View RGB (real color) images from the time series
#
# Data is available from Landsat-7 from April 1999. Data is available for Landsat-8 from April-2013 to now. A review of the available data shows that the Landdsat-7 scenes have a "banding" issue with the sensor that adds lines of "no data" to each scene. These can be removed by pixel screening but unfortunately some data is lost. So, for the selected time window and missions there are typically views of our region every 8 days. We will pick a scene with some clouds to demonstrate filtering to find the clear pixels.

# %%
# Test that packages work together
import xarray as xr
import dask
import dask.array as da
import zarr
import numpy as np

print("Package Versions:")
print(f"  xarray: {xr.__version__}")
print(f"  dask: {dask.__version__}")
print(f"  zarr: {zarr.__version__}")

# Test dask chunk manager
print("\nTesting dask chunk manager...")
try:
    test_array = da.ones((10, 10), chunks=(5, 5))
    test_xr = xr.DataArray(test_array)
    print(f"✓ Dask chunks working: {test_xr.chunks}")
except Exception as e:
    print(f"✗ Error: {e}")

print("\n✓ Ready to use!")
# Out:
# Package Versions:
#   xarray: 2025.3.1
#   dask: 2024.10.0
#   zarr: 2.17.2
#
# Testing dask chunk manager...
# ✓ Dask chunks working: ((5, 5), (5, 5))
#
# ✓ Ready to use!

# %%
plot_xx = xx[["red","green","blue"]].to_array()
plot_xx.plot.imshow(col='time', col_wrap=4, robust=True, vmin=0, vmax=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 2
#       1 plot_xx = xx[["red","green","blue"]].to_array()
# ----> 2 plot_xx.plot.imshow(col='time', col_wrap=4, robust=True, vmin=0, vmax=0.3)
#       3 plt.show()
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\plot\accessor.py:421, in DataArrayPlotAccessor.imshow(self, *args, **kwargs)
#     419 @functools.wraps(dataarray_plot.imshow, assigned=("__doc__",))
#     420 def imshow(self, *args, **kwargs) -> AxesImage | FacetGrid[DataArray]:
# --> 421     return dataarray_plot.imshow(self._da, *args, **kwargs)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\plot\dataarray_plot.py:1477, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1474     # Matplotlib does not support normalising RGB data, so do it here.
#    1475     # See eg. https://github.com/matplotlib/matplotlib/pull/10220
#    1476     if robust or vmax is not None or vmin is not None:
# -> 1477         darray = _rescale_imshow_rgb(darray.as_numpy(), vmin, vmax, robust)
#    1478         vmin, vmax, robust = None, None, False
#    1480 if subplot_kws is None:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\dataarray.py:854, in DataArray.as_numpy(self)
#     843 """
#     844 Coerces wrapped data and coordinates into numpy arrays, returning a DataArray.
#     845
#    (...)    851 DataArray.data
#     852 """
#     853 coords = {k: v.as_numpy() for k, v in self._coords.items()}
# --> 854 return self._replace(self.variable.as_numpy(), coords, indexes=self._indexes)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\core.py:864, in NamedArray.as_numpy(self)
#     862 def as_numpy(self) -> Self:
#     863     """Coerces wrapped data into a numpy array, returning a Variable."""
# --> 864     return self._replace(data=self.to_numpy())
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\core.py:860, in NamedArray.to_numpy(self)
#     858 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#     859 # TODO an entrypoint so array libraries can choose coercion method?
# --> 860 return to_numpy(self._data)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\pycompat.py:117, in to_numpy(data, **kwargs)
#     115 if is_chunked_array(data):
#     116     chunkmanager = get_chunked_array_type(data)
# --> 117     data, *_ = chunkmanager.compute(data, **kwargs)
#     118 if isinstance(data, array_type("cupy")):
#     119     data = data.get()
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:434, in _dask_loader_tyx(srcs, gbt, iyx, prefix_dims, postfix_dims, cfg, rdr, env, load_state, selection)
#     432 with rdr.restore_env(env, load_state):
#     433     for ti, ti_srcs in enumerate(srcs):
# --> 434         _fill_nd_slice(
#     435             ti_srcs, gbox, cfg, chunk[ti], ydim=ydim, selection=selection
#     436         )
#     437     return chunk
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:511, in _fill_nd_slice(srcs, dst_gbox, cfg, dst, ydim, selection)
#     508     return dst
#     510 src, *rest = srcs
# --> 511 yx_roi, pix = src.read(cfg, dst_gbox, dst=dst, selection=selection)
#     512 assert len(yx_roi) == 2
#     513 assert pix.ndim == dst.ndim
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:115, in RioReader.read(self, cfg, dst_geobox, dst, selection)
#     107 def read(
#     108     self,
#     109     cfg: RasterLoadParams,
#    (...)    113     selection: Optional[ReaderSubsetSelection] = None,
#     114 ) -> tuple[tuple[slice, slice], np.ndarray]:
# --> 115     return rio_read(self._src, cfg, dst_geobox, dst=dst, selection=selection)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:512, in rio_read(src, cfg, dst_geobox, dst, selection)
#     508     return roi, out.transpose([1, 2, 0])
#     510 try:
#     511     return fixup_out(
# --> 512         _rio_read(src, cfg, dst_geobox, prep_dst(dst), selection=selection)
#     513     )
#     514 except (
#     515     rasterio.errors.RasterioIOError,
#     516     rasterio.errors.RasterBlockError,
#     517     rasterio.errors.WarpOperationError,
#     518     rasterio.errors.WindowEvaluationError,
#     519 ) as e:
#     520     if cfg.fail_on_error:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:560, in _rio_read(src, cfg, dst_geobox, dst, selection)
#     549 def _rio_read(
#     550     src: RasterSource,
#     551     cfg: RasterLoadParams,
#    (...)    556     # if resampling is `nearest` then ignore sub-pixel translation when deciding
#     557     # whether we can just paste source into destination
#     558     ttol = 0.9 if cfg.nearest else 0.05
# --> 560     with rasterio.open(src.uri, "r", sharing=False) as rdr:
#     561         assert isinstance(rdr, rasterio.DatasetReader)
#     562         ovr_idx: Optional[int] = None
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py:368, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     365     path = _parse_path(raw_dataset_path)
#     367 if mode == "r":
# --> 368     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     369 elif mode == "r+":
#     370     dataset = get_writer_for_path(path, driver=driver)(
#     371         path, mode, driver=driver, sharing=sharing, **kwargs
#     372     )
#
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:357, in rasterio._err.exc_wrap_pointer()
#
# File rasterio\\_err.pyx:195, in rasterio._err.exc_check()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte

# %%
# Select a time slice to view a simple RGB image and the cloud mask
# See the XARRAY dimensions above for the number of time slices (starts at 0)

time_slice = 1

# %%
# Plot and RGB Real Color Image for a single date
fig, ax = plt.subplots(figsize=(8, 8))
xx.isel(time=time_slice)[["red", "green", "blue"]].to_array().plot.imshow(robust=True, ax=ax, vmin=0, vmax=0.3)
ax.set_title("RGB Real Color")
ax.axis('off')
plt.show()
# Out:
# Aborting load due to failure while reading: https://landsateuwest.blob.core.windows.net/landsat-c2/level-2/standard/oli-tirs/2015/170/079/LC08_L2SP_170079_20150204_20200909_02_T1/LC08_L2SP_170079_20150204_20200909_02_T1_SR_B2.TIF?st=2026-02-23T16%3A26%3A35Z&se=2026-02-24T17%3A11%3A35Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-02-24T07%3A41%3A28Z&ske=2026-03-03T07%3A41%3A28Z&sks=b&skv=2025-07-05&sig=U%2BNbQaniiAzYlXfV3Jf0LhOqbGI5MCL%2BmnjYY09BRag%3D:1
# Aborting load due to failure while reading: https://landsateuwest.blob.core.windows.net/landsat-c2/level-2/standard/oli-tirs/2015/170/079/LC08_L2SP_170079_20150204_20200909_02_T1/LC08_L2SP_170079_20150204_20200909_02_T1_SR_B3.TIF?st=2026-02-23T16%3A26%3A35Z&se=2026-02-24T17%3A11%3A35Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-02-24T07%3A41%3A28Z&ske=2026-03-03T07%3A41%3A28Z&sks=b&skv=2025-07-05&sig=U%2BNbQaniiAzYlXfV3Jf0LhOqbGI5MCL%2BmnjYY09BRag%3D:1
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsicurl/https://landsateuwest.blob.core.windows.net/landsat-c2/level-2/standard/oli-tirs/2015/170/079/LC08_L2SP_170079_20150204_20200909_02_T1/LC08_L2SP_170079_20150204_20200909_02_T1_SR_B2.TIF?st=2026-02-23T16%3A26%3A35Z&se=2026-02-24T17%3A11%3A35Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-02-24T07%3A41%3A28Z&ske=2026-03-03T07%3A41%3A28Z&sks=b&skv=2025-07-05&sig=U%2BNbQaniiAzYlXfV3Jf0LhOqbGI5MCL%2BmnjYY09BRag%3D' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Plot and RGB Real Color Image for a single date
#       2 fig, ax = plt.subplots(figsize=(8, 8))
# ----> 3 xx.isel(time=time_slice)[["red", "green", "blue"]].to_array().plot.imshow(robust=True, ax=ax, vmin=0, vmax=0.3)
#       4 ax.set_title("RGB Real Color")
#       5 ax.axis('off')
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\plot\accessor.py:421, in DataArrayPlotAccessor.imshow(self, *args, **kwargs)
#     419 @functools.wraps(dataarray_plot.imshow, assigned=("__doc__",))
#     420 def imshow(self, *args, **kwargs) -> AxesImage | FacetGrid[DataArray]:
# --> 421     return dataarray_plot.imshow(self._da, *args, **kwargs)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\plot\dataarray_plot.py:1477, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1474     # Matplotlib does not support normalising RGB data, so do it here.
#    1475     # See eg. https://github.com/matplotlib/matplotlib/pull/10220
#    1476     if robust or vmax is not None or vmin is not None:
# -> 1477         darray = _rescale_imshow_rgb(darray.as_numpy(), vmin, vmax, robust)
#    1478         vmin, vmax, robust = None, None, False
#    1480 if subplot_kws is None:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\dataarray.py:854, in DataArray.as_numpy(self)
#     843 """
#     844 Coerces wrapped data and coordinates into numpy arrays, returning a DataArray.
#     845
#    (...)    851 DataArray.data
#     852 """
#     853 coords = {k: v.as_numpy() for k, v in self._coords.items()}
# --> 854 return self._replace(self.variable.as_numpy(), coords, indexes=self._indexes)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\core.py:864, in NamedArray.as_numpy(self)
#     862 def as_numpy(self) -> Self:
#     863     """Coerces wrapped data into a numpy array, returning a Variable."""
# --> 864     return self._replace(data=self.to_numpy())
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\core.py:860, in NamedArray.to_numpy(self)
#     858 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#     859 # TODO an entrypoint so array libraries can choose coercion method?
# --> 860 return to_numpy(self._data)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\pycompat.py:117, in to_numpy(data, **kwargs)
#     115 if is_chunked_array(data):
#     116     chunkmanager = get_chunked_array_type(data)
# --> 117     data, *_ = chunkmanager.compute(data, **kwargs)
#     118 if isinstance(data, array_type("cupy")):
#     119     data = data.get()
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\namedarray\daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:434, in _dask_loader_tyx(srcs, gbt, iyx, prefix_dims, postfix_dims, cfg, rdr, env, load_state, selection)
#     432 with rdr.restore_env(env, load_state):
#     433     for ti, ti_srcs in enumerate(srcs):
# --> 434         _fill_nd_slice(
#     435             ti_srcs, gbox, cfg, chunk[ti], ydim=ydim, selection=selection
#     436         )
#     437     return chunk
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:511, in _fill_nd_slice(srcs, dst_gbox, cfg, dst, ydim, selection)
#     508     return dst
#     510 src, *rest = srcs
# --> 511 yx_roi, pix = src.read(cfg, dst_gbox, dst=dst, selection=selection)
#     512 assert len(yx_roi) == 2
#     513 assert pix.ndim == dst.ndim
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:115, in RioReader.read(self, cfg, dst_geobox, dst, selection)
#     107 def read(
#     108     self,
#     109     cfg: RasterLoadParams,
#    (...)    113     selection: Optional[ReaderSubsetSelection] = None,
#     114 ) -> tuple[tuple[slice, slice], np.ndarray]:
# --> 115     return rio_read(self._src, cfg, dst_geobox, dst=dst, selection=selection)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:526, in rio_read(src, cfg, dst_geobox, dst, selection)
#     520     if cfg.fail_on_error:
#     521         log.error(
#     522             "Aborting load due to failure while reading: %s:%d",
#     523             src.uri,
#     524             src.band,
#     525         )
# --> 526         raise e
#     527 except rasterio.errors.RasterioError as e:
#     528     if cfg.fail_on_error:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:512, in rio_read(src, cfg, dst_geobox, dst, selection)
#     508     return roi, out.transpose([1, 2, 0])
#     510 try:
#     511     return fixup_out(
# --> 512         _rio_read(src, cfg, dst_geobox, prep_dst(dst), selection=selection)
#     513     )
#     514 except (
#     515     rasterio.errors.RasterioIOError,
#     516     rasterio.errors.RasterBlockError,
#     517     rasterio.errors.WarpOperationError,
#     518     rasterio.errors.WindowEvaluationError,
#     519 ) as e:
#     520     if cfg.fail_on_error:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:560, in _rio_read(src, cfg, dst_geobox, dst, selection)
#     549 def _rio_read(
#     550     src: RasterSource,
#     551     cfg: RasterLoadParams,
#    (...)    556     # if resampling is `nearest` then ignore sub-pixel translation when deciding
#     557     # whether we can just paste source into destination
#     558     ttol = 0.9 if cfg.nearest else 0.05
# --> 560     with rasterio.open(src.uri, "r", sharing=False) as rdr:
#     561         assert isinstance(rdr, rasterio.DatasetReader)
#     562         ovr_idx: Optional[int] = None
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py:368, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     365     path = _parse_path(raw_dataset_path)
#     367 if mode == "r":
# --> 368     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     369 elif mode == "r+":
#     370     dataset = get_writer_for_path(path, driver=driver)(
#     371         path, mode, driver=driver, sharing=sharing, **kwargs
#     372     )
#
# File rasterio\\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: '/vsicurl/https://landsateuwest.blob.core.windows.net/landsat-c2/level-2/standard/oli-tirs/2015/170/079/LC08_L2SP_170079_20150204_20200909_02_T1/LC08_L2SP_170079_20150204_20200909_02_T1_SR_B2.TIF?st=2026-02-23T16%3A26%3A35Z&se=2026-02-24T17%3A11%3A35Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-02-24T07%3A41%3A28Z&ske=2026-03-03T07%3A41%3A28Z&sks=b&skv=2025-07-05&sig=U%2BNbQaniiAzYlXfV3Jf0LhOqbGI5MCL%2BmnjYY09BRag%3D' does not exist in the file system, and is not recognized as a supported dataset name.

# %% [markdown]
# ## Apply Cloud Filtering and Masking
#
# Cloud masking for Landsat Collection-2 Level-2 data can be complicated. The **"qa_pixel"**  band is used to assess each pixel and determine its cloud or water classification. The code below is credited to Mauricio Cordiero. See his webpage [HERE](https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/media/files/LSDS-1619_Landsat-8-9-C2-L2-ScienceProductGuide-v4.pdf) for a more detailed explanation of the process. Also, you can visit the Landsat-8 Collection-2 Level-2 Product Guide [HERE](https://www.usgs.gov/media/files/landsat-8-9-collection-2-level-2-science-product-guide) for more details about the cloud mask values. In the end, we are searching for clouds, cloud shadows, and water to create a mask for any given region. This will allow us to extract the "clear" pixels to assess the vegetation state.

# %%
# To mask the pixels and find clouds or water, it is best to use the bit values of the 16-bit qa_pixel flag
# See the website above for a nice explanation of the process

bit_flags = {
            'fill': 1<<0,
            'dilated_cloud': 1<<1,
            'cirrus': 1<<2, 
            'cloud': 1<<3,
            'shadow': 1<<4, 
            'snow': 1<<5, 
            'clear': 1<<6,
            'water': 1<<7
}

# %%
# Create a function that will mask pixels with a given type

def get_mask(mask, flags_list):
    
    # Create the result mask filled with zeros and the same shape as the mask
    final_mask = np.zeros_like(mask)
    
    # Loop through the flags  
    for flag in flags_list:
        
        # get the mask for each flag
        flag_mask = np.bitwise_and(mask, bit_flags[flag])
        
        # add it to the final flag
        final_mask = final_mask | flag_mask
    
    return final_mask > 0

# %%
# Pick a single time slice to view a mask with clouds and water
sample_xx = xx.isel(time=time_slice)

# %%
# Find the pixels that are no data (fill), clouds, cloud shadows, or water
my_mask = get_mask(sample_xx['qa_pixel'], ['fill', 'dilated_cloud', 'cirrus', 'cloud', 'shadow', 'water'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# Exception ignored in: 'rasterio._env.log_error'
# Traceback (most recent call last):
#   File "c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py", line 368, in open
#     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Find the pixels that are no data (fill), clouds, cloud shadows, or water
# ----> 2 my_mask = get_mask(sample_xx['qa_pixel'], ['fill', 'dilated_cloud', 'cirrus', 'cloud', 'shadow', 'water'])
#
# Cell In[22], line 6, in get_mask(mask, flags_list)
#       3 def get_mask(mask, flags_list):
#       4
#       5     # Create the result mask filled with zeros and the same shape as the mask
# ----> 6     final_mask = np.zeros_like(mask)
#       8     # Loop through the flags
#       9     for flag in flags_list:
#      10
#      11         # get the mask for each flag
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\numpy\_core\numeric.py:161, in zeros_like(a, dtype, order, subok, shape, device)
#      97 @array_function_dispatch(_zeros_like_dispatcher)
#      98 def zeros_like(
#      99     a, dtype=None, order='K', subok=True, shape=None, *, device=None
#     100 ):
#     101     """
#     102     Return an array of zeros with the same shape and type as a given array.
#     103
#    (...)    159
#     160     """
# --> 161     res = empty_like(
#     162         a, dtype=dtype, order=order, subok=subok, shape=shape, device=device
#     163     )
#     164     # needed instead of a 0 to get same result as zeros for string dtypes
#     165     z = zeros(1, dtype=res.dtype)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\common.py:181, in AbstractArray.__array__(self, dtype, copy)
#     179         except TypeError:
#     180             copy = False
# --> 181 return np.array(self.values, dtype=dtype, copy=copy)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\dataarray.py:823, in DataArray.values(self)
#     810 @property
#     811 def values(self) -> np.ndarray:
#     812     """
#     813     The array's data converted to numpy.ndarray.
#     814
#    (...)    821     to this array may be reflected in the DataArray as well.
#     822     """
# --> 823     return self.variable.values
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\variable.py:508, in Variable.values(self)
#     505 @property
#     506 def values(self) -> np.ndarray:
#     507     """The variable's data as a numpy.ndarray"""
# --> 508     return _as_array_or_item(self._data)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\xarray\core\variable.py:302, in _as_array_or_item(data)
#     288 def _as_array_or_item(data):
#     289     """Return the given values as a numpy array, or as an individual item if
#     290     it's a 0d datetime64 or timedelta64 array.
#     291
#    (...)    300     TODO: remove this (replace with np.asarray) once these issues are fixed
#     301     """
# --> 302     data = np.asarray(data)
#     303     if data.ndim == 0:
#     304         kind = data.dtype.kind
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\dask\array\core.py:1697, in Array.__array__(self, dtype, **kwargs)
#    1696 def __array__(self, dtype=None, **kwargs):
# -> 1697     x = self.compute()
#    1698     if dtype and x.dtype != dtype:
#    1699         x = x.astype(dtype)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\dask\base.py:372, in DaskMethodsMixin.compute(self, **kwargs)
#     348 def compute(self, **kwargs):
#     349     """Compute this dask collection
#     350
#     351     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    370     dask.compute
#     371     """
# --> 372     (result,) = compute(self, traverse=False, **kwargs)
#     373     return result
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\dask\base.py:660, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     657     postcomputes.append(x.__dask_postcompute__())
#     659 with shorten_traceback():
# --> 660     results = schedule(dsk, keys, **kwargs)
#     662 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:434, in _dask_loader_tyx(srcs, gbt, iyx, prefix_dims, postfix_dims, cfg, rdr, env, load_state, selection)
#     432 with rdr.restore_env(env, load_state):
#     433     for ti, ti_srcs in enumerate(srcs):
# --> 434         _fill_nd_slice(
#     435             ti_srcs, gbox, cfg, chunk[ti], ydim=ydim, selection=selection
#     436         )
#     437     return chunk
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_builder.py:511, in _fill_nd_slice(srcs, dst_gbox, cfg, dst, ydim, selection)
#     508     return dst
#     510 src, *rest = srcs
# --> 511 yx_roi, pix = src.read(cfg, dst_gbox, dst=dst, selection=selection)
#     512 assert len(yx_roi) == 2
#     513 assert pix.ndim == dst.ndim
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:115, in RioReader.read(self, cfg, dst_geobox, dst, selection)
#     107 def read(
#     108     self,
#     109     cfg: RasterLoadParams,
#    (...)    113     selection: Optional[ReaderSubsetSelection] = None,
#     114 ) -> tuple[tuple[slice, slice], np.ndarray]:
# --> 115     return rio_read(self._src, cfg, dst_geobox, dst=dst, selection=selection)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:512, in rio_read(src, cfg, dst_geobox, dst, selection)
#     508     return roi, out.transpose([1, 2, 0])
#     510 try:
#     511     return fixup_out(
# --> 512         _rio_read(src, cfg, dst_geobox, prep_dst(dst), selection=selection)
#     513     )
#     514 except (
#     515     rasterio.errors.RasterioIOError,
#     516     rasterio.errors.RasterBlockError,
#     517     rasterio.errors.WarpOperationError,
#     518     rasterio.errors.WindowEvaluationError,
#     519 ) as e:
#     520     if cfg.fail_on_error:
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\odc\loader\_rio.py:560, in _rio_read(src, cfg, dst_geobox, dst, selection)
#     549 def _rio_read(
#     550     src: RasterSource,
#     551     cfg: RasterLoadParams,
#    (...)    556     # if resampling is `nearest` then ignore sub-pixel translation when deciding
#     557     # whether we can just paste source into destination
#     558     ttol = 0.9 if cfg.nearest else 0.05
# --> 560     with rasterio.open(src.uri, "r", sharing=False) as rdr:
#     561         assert isinstance(rdr, rasterio.DatasetReader)
#     562         ovr_idx: Optional[int] = None
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\celso\OneDrive\Área de Trabalho\Work In Progress\EY-AI-and-Data-Challenge-main\EY-AI-and-Data-Challenge-main\.venv\Lib\site-packages\rasterio\__init__.py:368, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     365     path = _parse_path(raw_dataset_path)
#     367 if mode == "r":
# --> 368     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     369 elif mode == "r+":
#     370     dataset = get_writer_for_path(path, driver=driver)(
#     371         path, mode, driver=driver, sharing=sharing, **kwargs
#     372     )
#
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:357, in rasterio._err.exc_wrap_pointer()
#
# File rasterio\\_err.pyx:195, in rasterio._err.exc_check()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc1 in position 77: invalid start byte

# %%
# Show only the mask (Yellow) with valid data in Purple
plt.figure(figsize=(7,7))
plt.imshow(my_mask)
plt.title("Cloud / Shadows / Water Mask > YELLOW")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Show only the mask (Yellow) with valid data in Purple
#       2 plt.figure(figsize=(7,7))
# ----> 3 plt.imshow(my_mask)
#       4 plt.title("Cloud / Shadows / Water Mask > YELLOW")
#       5 plt.axis('off')
#
# NameError: name 'my_mask' is not defined

# %% [markdown]
# ### Prepare a data mask before plotting sample products

# %%
# Calculate the mask for the entire xarray (all time slices)
full_mask = get_mask(xx['qa_pixel'], ['fill', 'dilated_cloud', 'cirrus', 'cloud', 'shadow', 'water'])

# %%
# Create a "clean" dataset with the mask applied 
cleaned_data = xx.where(~full_mask)

# %% [markdown]
# ### Normalized Difference Vegetation Index (NDVI)
#
# The **Normalized Difference Vegetation Index (NDVI)** is used to measure the "greenness" of vegetation and has a range of 0.0 to 1.0. Low values (0.0 to 0.25) reflect a lack of vegetation (bare soil, water), middle values (0.25 to 0.6) reflect crops in their growing state, and high values (0.6 to 1.0) reflect crops at their peak vegetation state. The equation uses two spectral bands where: **NDVI = (NIR-Red) / (NIR+Red)**.

# %%
# Plot an NDVI image for a single date with few clouds
fig = plt.figure(figsize=(10, 7))
ndvi_image = (cleaned_data.nir08-cleaned_data.red)/(cleaned_data.nir08+cleaned_data.red)
ndvi_image.isel(time=time_slice).plot(vmin=0.0, vmax=0.8, cmap="RdYlGn")
plt.title("NDVI")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Normalized Difference Moisture Index (NDMI)
#
# The **Normalized Difference Moisture Index (NDVI)** is used to measure the presence of soil moisture stress level of vegetation and has a range of -1.0 to 1.0. Higher values (0.4 to 1.0) indicate high vegetation water content, often seen in healthy, well-irrigated areas. Lower values (0 to 0.2) suggest low water content or potential water stress. Very low values (-1.0 to 0.0) typically correspond to bare soil or areas with little to no vegetation moisture. The equation uses two spectral bands where: **NDMI = (NIR-SWIR16) / (NIR+SWIR16)**.

# %%
# Plot an NDMI image for a single date with few clouds
fig = plt.figure(figsize=(10, 7))
ndvi_image = (cleaned_data.nir08-cleaned_data.swir16)/(cleaned_data.nir08+cleaned_data.swir16)
ndvi_image.isel(time=time_slice).plot(vmin=-0.2, vmax=0.7, cmap="jet_r")
plt.title("NDMI")
plt.axis('off')
plt.show()

# %% [markdown]
# ### SWIR-22 (Shortwave Infrared #2)
# The Shortwave Infrared #2 band (SWIR22) has a wavelength range of 2.11 to 2.29 microns. This band is typically used for characterizing vegetation and land cover, with applications in estimating fractional crop residue cover, monitoring crop health, and distinguishing soil from vegetation. It is a critical tool for long-term land use analysis and change detection in agriculture, forestry, and coastal environments.

# %%
# Plot an SWIR-22 image for a single date with few clouds
fig = plt.figure(figsize=(10, 7))
swir22_image = cleaned_data.swir22
swir22_image.isel(time=time_slice).plot(vmin=0.0, vmax=0.3, cmap="Greys")
plt.title("SWIR22")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Conclusion
#
# Congratulations! You have successfully connected your Snowflake account to an external API, processed a variety of geospatial data, and generated complex visuals.
#
# ### We wish you and your team the best of luck in the Data Challenge!
